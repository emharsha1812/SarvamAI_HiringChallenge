# %%
import pandas as pd
import numpy as np

# %%
import os
import shutil

# Define the mapping
bible_mappings = {
    "mat": "Matthew",
    "mrk": "Mark",
    "luk": "Luke",
    "jhn": "John",
    "act": "Acts",
    "rom": "Romans",
    "1co": "1Corinthians",
    "2co": "2Corinthians",
    "3co": "3Corinthians",
    "gal": "Galatians",
    "eph": "Ephesians",
    "php": "Philippians",
    "col": "Colossians",
    "1th": "1Thessalonians",
    "2th": "2Thessalonians",
    "1ti": "1Timothy",
    "2ti": "2Timothy",
    "tit": "Titus",
    "phm": "Philemon",
    "heb": "Hebrews",
    "jas": "James",
    "1pe": "1Peter",
    "2pe": "2Peter",
    "1jn": "1John",
    "2jn": "2John",
    "3jn": "3John",
    "jud": "Jude",
    "rev": "Revelation"
}

# Paths to the folders containing audio and text files
audio_folder = "marathi_audio"
text_folder = "marathi_text"
output_folder = "organized_files"

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to get the new name for the file
def get_new_name(file, is_audio):
    try:
        parts = file.split('___')
        print(parts)
        number = parts[1]
        print("I am here")
        book_code = parts[2].split('_')[0].lower()  # Convert to lowercase
        print(f"This is book code:{book_code}")
        book_name = bible_mappings[book_code]
        if is_audio:
            return f"{number}_{book_name}.mp3"
        else:
            return f"{number}_{book_name}.txt"
    except Exception as e:
        print(f"Error processing file {file}: {e}")
        return None

# Iterate over audio files and rename/move them
for audio_file in os.listdir(audio_folder):
    if audio_file.endswith(".mp3"):
        new_name = get_new_name(audio_file, True)
        if new_name:
            chapter = new_name.split('_')[0]
            book_name = new_name.split('_')[1].replace('.mp3', '')

            # Create folder for each book and chapter if it doesn't exist
            new_folder_path = os.path.join(output_folder, f"{chapter}_{book_name}")
            if not os.path.exists(new_folder_path):
                os.makedirs(new_folder_path)

            # Move and rename audio file
            src_audio_path = os.path.join(audio_folder, audio_file)
            dst_audio_path = os.path.join(new_folder_path, new_name)
            shutil.copy2(src_audio_path, dst_audio_path)

# Iterate over text files and rename/move them
for text_file in os.listdir(text_folder):
    if text_file.endswith(".txt"):
        book_code, chapter = text_file.split('_')[0].lower(), text_file.split('_')[2].replace('.txt', '')
        book_name = bible_mappings[book_code]

        # Create the same folder structure for text files
        new_folder_name = f"{chapter}_{book_name}"
        new_folder_path = os.path.join(output_folder, new_folder_name)
        if not os.path.exists(new_folder_path):
            os.makedirs(new_folder_path)

        new_name = f"{chapter}_{book_name}.txt"
        src_text_path = os.path.join(text_folder, text_file)
        dst_text_path = os.path.join(new_folder_path, new_name)
        shutil.copy2(src_text_path, dst_text_path)

print("Files have been successfully organized and renamed.")
# Out:
# ['B01', '01_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___01_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '02_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___02_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '03_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___03_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '04_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___04_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '05_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___05_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '06_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___06_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '07_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___07_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '08_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___08_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '09_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___09_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '10_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___10_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '11_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___11_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '12_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___12_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '13_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___13_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '14_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___14_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '15_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___15_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '16_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___16_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '17_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___17_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '18_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___18_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '19_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___19_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '20_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___20_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '21_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___21_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '22_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___22_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '23_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___23_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '24_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___24_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '25_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___25_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '26_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___26_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '27_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___27_Matthew_____MARWTCN1DA.mp3: ''
# ['B01', '28_Matthew', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B01___28_Matthew_____MARWTCN1DA.mp3: ''
# ['B02', '01_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___01_Mark________MARWTCN1DA.mp3: ''
# ['B02', '02_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___02_Mark________MARWTCN1DA.mp3: ''
# ['B02', '03_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___03_Mark________MARWTCN1DA.mp3: ''
# ['B02', '04_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___04_Mark________MARWTCN1DA.mp3: ''
# ['B02', '05_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___05_Mark________MARWTCN1DA.mp3: ''
# ['B02', '06_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___06_Mark________MARWTCN1DA.mp3: ''
# ['B02', '07_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___07_Mark________MARWTCN1DA.mp3: ''
# ['B02', '08_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___08_Mark________MARWTCN1DA.mp3: ''
# ['B02', '09_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___09_Mark________MARWTCN1DA.mp3: ''
# ['B02', '10_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___10_Mark________MARWTCN1DA.mp3: ''
# ['B02', '11_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___11_Mark________MARWTCN1DA.mp3: ''
# ['B02', '12_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___12_Mark________MARWTCN1DA.mp3: ''
# ['B02', '13_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___13_Mark________MARWTCN1DA.mp3: ''
# ['B02', '14_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___14_Mark________MARWTCN1DA.mp3: ''
# ['B02', '15_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___15_Mark________MARWTCN1DA.mp3: ''
# ['B02', '16_Mark', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B02___16_Mark________MARWTCN1DA.mp3: ''
# ['B03', '01_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___01_Luke________MARWTCN1DA.mp3: ''
# ['B03', '02_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___02_Luke________MARWTCN1DA.mp3: ''
# ['B03', '03_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___03_Luke________MARWTCN1DA.mp3: ''
# ['B03', '04_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___04_Luke________MARWTCN1DA.mp3: ''
# ['B03', '05_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___05_Luke________MARWTCN1DA.mp3: ''
# ['B03', '06_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___06_Luke________MARWTCN1DA.mp3: ''
# ['B03', '07_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___07_Luke________MARWTCN1DA.mp3: ''
# ['B03', '08_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___08_Luke________MARWTCN1DA.mp3: ''
# ['B03', '09_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___09_Luke________MARWTCN1DA.mp3: ''
# ['B03', '10_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___10_Luke________MARWTCN1DA.mp3: ''
# ['B03', '11_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___11_Luke________MARWTCN1DA.mp3: ''
# ['B03', '12_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___12_Luke________MARWTCN1DA.mp3: ''
# ['B03', '13_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___13_Luke________MARWTCN1DA.mp3: ''
# ['B03', '14_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___14_Luke________MARWTCN1DA.mp3: ''
# ['B03', '15_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___15_Luke________MARWTCN1DA.mp3: ''
# ['B03', '16_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___16_Luke________MARWTCN1DA.mp3: ''
# ['B03', '17_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___17_Luke________MARWTCN1DA.mp3: ''
# ['B03', '18_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___18_Luke________MARWTCN1DA.mp3: ''
# ['B03', '19_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___19_Luke________MARWTCN1DA.mp3: ''
# ['B03', '20_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___20_Luke________MARWTCN1DA.mp3: ''
# ['B03', '21_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___21_Luke________MARWTCN1DA.mp3: ''
# ['B03', '22_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___22_Luke________MARWTCN1DA.mp3: ''
# ['B03', '23_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___23_Luke________MARWTCN1DA.mp3: ''
# ['B03', '24_Luke', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B03___24_Luke________MARWTCN1DA.mp3: ''
# ['B04', '01_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___01_John________MARWTCN1DA.mp3: ''
# ['B04', '02_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___02_John________MARWTCN1DA.mp3: ''
# ['B04', '03_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___03_John________MARWTCN1DA.mp3: ''
# ['B04', '04_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___04_John________MARWTCN1DA.mp3: ''
# ['B04', '05_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___05_John________MARWTCN1DA.mp3: ''
# ['B04', '06_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___06_John________MARWTCN1DA.mp3: ''
# ['B04', '07_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___07_John________MARWTCN1DA.mp3: ''
# ['B04', '08_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___08_John________MARWTCN1DA.mp3: ''
# ['B04', '09_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___09_John________MARWTCN1DA.mp3: ''
# ['B04', '10_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___10_John________MARWTCN1DA.mp3: ''
# ['B04', '11_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___11_John________MARWTCN1DA.mp3: ''
# ['B04', '12_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___12_John________MARWTCN1DA.mp3: ''
# ['B04', '13_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___13_John________MARWTCN1DA.mp3: ''
# ['B04', '14_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___14_John________MARWTCN1DA.mp3: ''
# ['B04', '15_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___15_John________MARWTCN1DA.mp3: ''
# ['B04', '16_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___16_John________MARWTCN1DA.mp3: ''
# ['B04', '17_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___17_John________MARWTCN1DA.mp3: ''
# ['B04', '18_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___18_John________MARWTCN1DA.mp3: ''
# ['B04', '19_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___19_John________MARWTCN1DA.mp3: ''
# ['B04', '20_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___20_John________MARWTCN1DA.mp3: ''
# ['B04', '21_John', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B04___21_John________MARWTCN1DA.mp3: ''
# ['B05', '01_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___01_Acts________MARWTCN1DA.mp3: ''
# ['B05', '02_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___02_Acts________MARWTCN1DA.mp3: ''
# ['B05', '03_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___03_Acts________MARWTCN1DA.mp3: ''
# ['B05', '04_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___04_Acts________MARWTCN1DA.mp3: ''
# ['B05', '05_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___05_Acts________MARWTCN1DA.mp3: ''
# ['B05', '06_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___06_Acts________MARWTCN1DA.mp3: ''
# ['B05', '07_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___07_Acts________MARWTCN1DA.mp3: ''
# ['B05', '08_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___08_Acts________MARWTCN1DA.mp3: ''
# ['B05', '09_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___09_Acts________MARWTCN1DA.mp3: ''
# ['B05', '10_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___10_Acts________MARWTCN1DA.mp3: ''
# ['B05', '11_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___11_Acts________MARWTCN1DA.mp3: ''
# ['B05', '12_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___12_Acts________MARWTCN1DA.mp3: ''
# ['B05', '13_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___13_Acts________MARWTCN1DA.mp3: ''
# ['B05', '14_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___14_Acts________MARWTCN1DA.mp3: ''
# ['B05', '15_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___15_Acts________MARWTCN1DA.mp3: ''
# ['B05', '16_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___16_Acts________MARWTCN1DA.mp3: ''
# ['B05', '17_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___17_Acts________MARWTCN1DA.mp3: ''
# ['B05', '18_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___18_Acts________MARWTCN1DA.mp3: ''
# ['B05', '19_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___19_Acts________MARWTCN1DA.mp3: ''
# ['B05', '20_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___20_Acts________MARWTCN1DA.mp3: ''
# ['B05', '21_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___21_Acts________MARWTCN1DA.mp3: ''
# ['B05', '22_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___22_Acts________MARWTCN1DA.mp3: ''
# ['B05', '23_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___23_Acts________MARWTCN1DA.mp3: ''
# ['B05', '24_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___24_Acts________MARWTCN1DA.mp3: ''
# ['B05', '25_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___25_Acts________MARWTCN1DA.mp3: ''
# ['B05', '26_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___26_Acts________MARWTCN1DA.mp3: ''
# ['B05', '27_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___27_Acts________MARWTCN1DA.mp3: ''
# ['B05', '28_Acts', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B05___28_Acts________MARWTCN1DA.mp3: ''
# ['B06', '01_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___01_Romans______MARWTCN1DA.mp3: ''
# ['B06', '02_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___02_Romans______MARWTCN1DA.mp3: ''
# ['B06', '03_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___03_Romans______MARWTCN1DA.mp3: ''
# ['B06', '04_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___04_Romans______MARWTCN1DA.mp3: ''
# ['B06', '05_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___05_Romans______MARWTCN1DA.mp3: ''
# ['B06', '06_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___06_Romans______MARWTCN1DA.mp3: ''
# ['B06', '07_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___07_Romans______MARWTCN1DA.mp3: ''
# ['B06', '08_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___08_Romans______MARWTCN1DA.mp3: ''
# ['B06', '09_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___09_Romans______MARWTCN1DA.mp3: ''
# ['B06', '10_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___10_Romans______MARWTCN1DA.mp3: ''
# ['B06', '11_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___11_Romans______MARWTCN1DA.mp3: ''
# ['B06', '12_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___12_Romans______MARWTCN1DA.mp3: ''
# ['B06', '13_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___13_Romans______MARWTCN1DA.mp3: ''
# ['B06', '14_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___14_Romans______MARWTCN1DA.mp3: ''
# ['B06', '15_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___15_Romans______MARWTCN1DA.mp3: ''
# ['B06', '16_Romans', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B06___16_Romans______MARWTCN1DA.mp3: ''
# ['B07', '01_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___01_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '02_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___02_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '03_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___03_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '04_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___04_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '05_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___05_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '06_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___06_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '07_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___07_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '08_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___08_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '09_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___09_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '10_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___10_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '11_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___11_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '12_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___12_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '13_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___13_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '14_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___14_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '15_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___15_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B07', '16_1CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B07___16_1CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '01_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___01_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '02_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___02_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '03_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___03_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '04_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___04_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '05_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___05_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '06_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___06_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '07_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___07_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '08_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___08_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '09_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___09_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '10_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___10_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '11_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___11_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '12_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___12_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B08', '13_2CorinthiansMARWTCN1DA.mp3']
# I am here
# Error processing file B08___13_2CorinthiansMARWTCN1DA.mp3: list index out of range
# ['B09', '01_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___01_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B09', '02_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___02_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B09', '03_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___03_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B09', '04_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___04_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B09', '05_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___05_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B09', '06_Galatians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B09___06_Galatians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '01_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___01_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '02_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___02_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '03_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___03_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '04_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___04_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '05_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___05_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B10', '06_Ephesians', 'MARWTCN1DA.mp3']
# I am here
# This is book code:marwtcn1da.mp3
# Error processing file B10___06_Ephesians___MARWTCN1DA.mp3: 'marwtcn1da.mp3'
# ['B11', '01_Philippians_MARWTCN1DA.mp3']
# I am here
# Error processing file B11___01_Philippians_MARWTCN1DA.mp3: list index out of range
# ['B11', '02_Philippians_MARWTCN1DA.mp3']
# I am here
# Error processing file B11___02_Philippians_MARWTCN1DA.mp3: list index out of range
# ['B11', '03_Philippians_MARWTCN1DA.mp3']
# I am here
# Error processing file B11___03_Philippians_MARWTCN1DA.mp3: list index out of range
# ['B11', '04_Philippians_MARWTCN1DA.mp3']
# I am here
# Error processing file B11___04_Philippians_MARWTCN1DA.mp3: list index out of range
# ['B12', '01_Colossians__MARWTCN1DA.mp3']
# I am here
# Error processing file B12___01_Colossians__MARWTCN1DA.mp3: list index out of range
# ['B12', '02_Colossians__MARWTCN1DA.mp3']
# I am here
# Error processing file B12___02_Colossians__MARWTCN1DA.mp3: list index out of range
# ['B12', '03_Colossians__MARWTCN1DA.mp3']
# I am here
# Error processing file B12___03_Colossians__MARWTCN1DA.mp3: list index out of range
# ['B12', '04_Colossians__MARWTCN1DA.mp3']
# I am here
# Error processing file B12___04_Colossians__MARWTCN1DA.mp3: list index out of range
# ['B13', '01_1Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B13___01_1Thess______MARWTCN1DA.mp3: ''
# ['B13', '02_1Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B13___02_1Thess______MARWTCN1DA.mp3: ''
# ['B13', '03_1Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B13___03_1Thess______MARWTCN1DA.mp3: ''
# ['B13', '04_1Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B13___04_1Thess______MARWTCN1DA.mp3: ''
# ['B13', '05_1Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B13___05_1Thess______MARWTCN1DA.mp3: ''
# ['B14', '01_2Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B14___01_2Thess______MARWTCN1DA.mp3: ''
# ['B14', '02_2Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B14___02_2Thess______MARWTCN1DA.mp3: ''
# ['B14', '03_2Thess', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B14___03_2Thess______MARWTCN1DA.mp3: ''
# ['B15', '01_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___01_1Timothy____MARWTCN1DA.mp3: ''
# ['B15', '02_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___02_1Timothy____MARWTCN1DA.mp3: ''
# ['B15', '03_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___03_1Timothy____MARWTCN1DA.mp3: ''
# ['B15', '04_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___04_1Timothy____MARWTCN1DA.mp3: ''
# ['B15', '05_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___05_1Timothy____MARWTCN1DA.mp3: ''
# ['B15', '06_1Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B15___06_1Timothy____MARWTCN1DA.mp3: ''
# ['B16', '01_2Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B16___01_2Timothy____MARWTCN1DA.mp3: ''
# ['B16', '02_2Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B16___02_2Timothy____MARWTCN1DA.mp3: ''
# ['B16', '03_2Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B16___03_2Timothy____MARWTCN1DA.mp3: ''
# ['B16', '04_2Timothy', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B16___04_2Timothy____MARWTCN1DA.mp3: ''
# ['B17', '01_Titus', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B17___01_Titus_______MARWTCN1DA.mp3: ''
# ['B17', '02_Titus', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B17___02_Titus_______MARWTCN1DA.mp3: ''
# ['B17', '03_Titus', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B17___03_Titus_______MARWTCN1DA.mp3: ''
# ['B18', '01_Philemon', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B18___01_Philemon____MARWTCN1DA.mp3: ''
# ['B19', '01_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___01_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '02_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___02_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '03_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___03_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '04_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___04_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '05_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___05_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '06_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___06_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '07_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___07_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '08_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___08_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '09_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___09_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '10_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___10_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '11_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___11_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '12_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___12_Hebrews_____MARWTCN1DA.mp3: ''
# ['B19', '13_Hebrews', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B19___13_Hebrews_____MARWTCN1DA.mp3: ''
# ['B20', '01_James', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B20___01_James_______MARWTCN1DA.mp3: ''
# ['B20', '02_James', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B20___02_James_______MARWTCN1DA.mp3: ''
# ['B20', '03_James', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B20___03_James_______MARWTCN1DA.mp3: ''
# ['B20', '04_James', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B20___04_James_______MARWTCN1DA.mp3: ''
# ['B20', '05_James', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B20___05_James_______MARWTCN1DA.mp3: ''
# ['B21', '01_1Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B21___01_1Peter______MARWTCN1DA.mp3: ''
# ['B21', '02_1Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B21___02_1Peter______MARWTCN1DA.mp3: ''
# ['B21', '03_1Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B21___03_1Peter______MARWTCN1DA.mp3: ''
# ['B21', '04_1Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B21___04_1Peter______MARWTCN1DA.mp3: ''
# ['B21', '05_1Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B21___05_1Peter______MARWTCN1DA.mp3: ''
# ['B22', '01_2Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B22___01_2Peter______MARWTCN1DA.mp3: ''
# ['B22', '02_2Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B22___02_2Peter______MARWTCN1DA.mp3: ''
# ['B22', '03_2Peter', '', 'MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B22___03_2Peter______MARWTCN1DA.mp3: ''
# ['B23', '01_1John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B23___01_1John_______MARWTCN1DA.mp3: ''
# ['B23', '02_1John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B23___02_1John_______MARWTCN1DA.mp3: ''
# ['B23', '03_1John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B23___03_1John_______MARWTCN1DA.mp3: ''
# ['B23', '04_1John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B23___04_1John_______MARWTCN1DA.mp3: ''
# ['B23', '05_1John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B23___05_1John_______MARWTCN1DA.mp3: ''
# ['B24', '01_2John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B24___01_2John_______MARWTCN1DA.mp3: ''
# ['B25', '01_3John', '', '_MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B25___01_3John_______MARWTCN1DA.mp3: ''
# ['B26', '01_Jude', '', '__MARWTCN1DA.mp3']
# I am here
# This is book code:
# Error processing file B26___01_Jude________MARWTCN1DA.mp3: ''
# ['B27', '01_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___01_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '02_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___02_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '03_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___03_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '04_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___04_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '05_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___05_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '06_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___06_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '07_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___07_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '08_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___08_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '09_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___09_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '10_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___10_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '11_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___11_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '12_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___12_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '13_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___13_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '14_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___14_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '15_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___15_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '16_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___16_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '17_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___17_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '18_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___18_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '19_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___19_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '20_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___20_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '21_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___21_Revelation__MARWTCN1DA.mp3: list index out of range
# ['B27', '22_Revelation__MARWTCN1DA.mp3']
# I am here
# Error processing file B27___22_Revelation__MARWTCN1DA.mp3: list index out of range
# Files have been successfully organized and renamed.
